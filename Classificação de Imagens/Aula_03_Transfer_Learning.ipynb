# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
# %cd /content/drive/MyDrive/SEMAC/
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/SEMAC

# %% [markdown]
# ##**DATASET**
# > Para esta aula, utilizaremos um dataset um pouco mais complexo, composto de imagens de células do sangue (hemácias), onde desejaremos classificar se são cancerígenas ou não.
#
# > O dataset possui 4 classes:
# * Benigna
# * Maligna Pre-B
# * Maligna Pro-B
# * Maligna Early Pre-B
#
# > _Link para o Dataset:_
# https://www.kaggle.com/datasets/mohammadamireshraghi/blood-cell-cancer-all-4class?resource=download-directory
# ---

# %%
# !unzip Dataset.zip -d dataset/
# Out:
# Archive:  Dataset.zip
#   inflating: dataset/Benign/Sap_013 (1).jpg
#   inflating: dataset/Benign/Sap_013 (10).jpg
#   inflating: dataset/Benign/Sap_013 (11).jpg
#   inflating: dataset/Benign/Sap_013 (12).jpg
#   inflating: dataset/Benign/Sap_013 (13).jpg
#   inflating: dataset/Benign/Sap_013 (14).jpg
#   inflating: dataset/Benign/Sap_013 (15).jpg
#   inflating: dataset/Benign/Sap_013 (16).jpg
#   inflating: dataset/Benign/Sap_013 (17).jpg
#   inflating: dataset/Benign/Sap_013 (18).jpg
#   inflating: dataset/Benign/Sap_013 (19).jpg
#   inflating: dataset/Benign/Sap_013 (2).jpg
#   inflating: dataset/Benign/Sap_013 (20).jpg
#   inflating: dataset/Benign/Sap_013 (21).jpg
#   inflating: dataset/Benign/Sap_013 (23).jpg
#   inflating: dataset/Benign/Sap_013 (24).jpg
#   inflating: dataset/Benign/Sap_013 (25).jpg
#   inflating: dataset/Benign/Sap_013 (26).jpg
#   inflating: dataset/Benign/Sap_013 (27).jpg
#   inflating: dataset/Benign/Sap_013 (28).jpg
#   inflating: dataset/Benign/Sap_013 (29).jpg
#   inflating: dataset/Benign/Sap_013 (3).jpg
#   inflating: dataset/Benign/Sap_013 (30).jpg
#   inflating: dataset/Benign/Sap_013 (31).jpg
#   inflating: dataset/Benign/Sap_013 (32).jpg
#   inflating: dataset/Benign/Sap_013 (33).jpg
#   inflating: dataset/Benign/Sap_013 (34).jpg
#   inflating: dataset/Benign/Sap_013 (35).jpg
#   inflating: dataset/Benign/Sap_013 (36).jpg
#   inflating: dataset/Benign/Sap_013 (37).jpg
#   inflating: dataset/Benign/Sap_013 (38).jpg
#   inflating: dataset/Benign/Sap_013 (39).jpg
#   inflating: dataset/Benign/Sap_013 (4).jpg
#   inflating: dataset/Benign/Sap_013 (40).jpg
#   inflating: dataset/Benign/Sap_013 (41).jpg
#   inflating: dataset/Benign/Sap_013 (42).jpg
#   inflating: dataset/Benign/Sap_013 (43).jpg
#   inflating: dataset/Benign/Sap_013 (44).jpg
#   inflating: dataset/Benign/Sap_013 (5).jpg
#   inflating: dataset/Benign/Sap_013 (7).jpg
#   inflating: dataset/Benign/Sap_013 (8).jpg
#   inflating: dataset/Benign/Sap_013 (9).jpg
#   inflating: dataset/Benign/Snap_001 (2).jpg
#   inflating: dataset/Benign/Snap_001 (3).jpg
#   inflating: dataset/Benign/Snap_001 (4).jpg
#   inflating: dataset/Benign/Snap_001.jpg
#   inflating: dataset/Benign/Snap_002 (2).jpg
#   inflating: dataset/Benign/Snap_002 (3).jpg
#   inflating: dataset/Benign/Snap_002 (4).jpg
#   inflating: dataset/Benign/Snap_002.jpg
#   inflating: dataset/Benign/Snap_003 (2).jpg
#   inflating: dataset/Benign/Snap_003 (3).jpg
#   inflating: dataset/Benign/Snap_003 (4).jpg
#   inflating: dataset/Benign/Snap_003.jpg
#   inflating: dataset/Benign/Snap_004 (2).jpg
#   inflating: dataset/Benign/Snap_004 (3).jpg
#   inflating: dataset/Benign/Snap_004 (4).jpg
#   inflating: dataset/Benign/Snap_004.jpg
#   inflating: dataset/Benign/Snap_005 (2).jpg
#   inflating: dataset/Benign/Snap_005 (3).jpg
#   inflating: dataset/Benign/Snap_005.jpg
#   inflating: dataset/Benign/Snap_006 (2).jpg
#   inflating: dataset/Benign/Snap_006 (3).jpg
#   inflating: dataset/Benign/Snap_006.jpg
#   inflating: dataset/Benign/Snap_007 (2).jpg
#   inflating: dataset/Benign/Snap_007 (3).jpg
#   inflating: dataset/Benign/Snap_007 (4).jpg
#   inflating: dataset/Benign/Snap_007.jpg
#   inflating: dataset/Benign/Snap_008 (2).jpg
#   inflating: dataset/Benign/Snap_008 (3).jpg
#   inflating: dataset/Benign/Snap_008 (4).jpg
#   inflating: dataset/Benign/Snap_008.jpg
#   inflating: dataset/Benign/Snap_009 (2).jpg
#   inflating: dataset/Benign/Snap_009 (3).jpg
#   inflating: dataset/Benign/Snap_009 (4).jpg
#   inflating: dataset/Benign/Snap_009.jpg
#   inflating: dataset/Benign/Snap_010 (2).jpg
#   inflating: dataset/Benign/Snap_010 (3).jpg
#   inflating: dataset/Benign/Snap_010 (4).jpg
#   inflating: dataset/Benign/Snap_010.jpg
#   inflating: dataset/Benign/Snap_011 (2).jpg
#   inflating: dataset/Benign/Snap_011 (3).jpg
#   inflating: dataset/Benign/Snap_011 (4).jpg
#   inflating: dataset/Benign/Snap_011.jpg
#   inflating: dataset/Benign/Snap_012 (2).jpg
#   inflating: dataset/Benign/Snap_012 (4).jpg
#   inflating: dataset/Benign/Snap_012.jpg
#   inflating: dataset/Benign/Snap_013 (2).jpg
#   inflating: dataset/Benign/Snap_013 (3).jpg
#   inflating: dataset/Benign/Snap_013 (4).jpg
#   inflating: dataset/Benign/Snap_014 (2).jpg
#   inflating: dataset/Benign/Snap_014 (3).jpg
#   inflating: dataset/Benign/Snap_014 (4).jpg
#   inflating: dataset/Benign/Snap_014.jpg
#   inflating: dataset/Benign/Snap_015 (2).jpg
#   inflating: dataset/Benign/Snap_015 (3).jpg
#   inflating: dataset/Benign/Snap_015 (4).jpg
#   inflating: dataset/Benign/Snap_015.jpg
#   inflating: dataset/Benign/Snap_016 (2).jpg
#   inflating: dataset/Benign/Snap_016 (3).jpg
#   inflating: dataset/Benign/Snap_016 (4).jpg
#   inflating: dataset/Benign/Snap_016.jpg
#
# ---

# %%
# Função que retorna uma lista com os nomes dos arquivos presentes no diretório para que as imagens possam ser acessadas individualmente
benign = os.listdir("./dataset/Benign/")
pro_b = os.listdir("./dataset/[Malignant] Pro-B/")
pre_b = os.listdir("./dataset/[Malignant] Pre-B/")
early_pre_b = os.listdir("./dataset/[Malignant] early Pre-B/")

print("Qtd benigno:", len(benign))
print("Qtd maligno pro-b:", len(pro_b))
print("Qtd maligno pre-b:", len(pre_b))
print("Qtd maligno early pre-b:", len(early_pre_b))
# Out:
# Qtd benigno: 512
# Qtd maligno pro-b: 796
# Qtd maligno pre-b: 955
# Qtd maligno early pre-b: 979

# %%
pathBenign = "./dataset/Benign/"
# Foram escolhidos ângulos múltiplos de 90° para evitar que apareçam bordas pretas na imagem após a transformação
interRot = [90, 180, 270]
escolher = [0, 1, 2]

contador = 300
for img in benign[:300]:
  print(f'Faltam {contador} imagens');
  image = Image.open(os.path.join(pathBenign, img))

  opcao = int(random.random() * len(escolher))
  if opcao == 0:
    # Inversão horizontal da imagem
    horiz_img = image.transpose(method=Image.FLIP_LEFT_RIGHT)
    horiz_img.save(os.path.join(pathBenign, f"hor_flip_" + img))

  elif opcao == 1:
    # Rotação da imagem por um ângulo de 90°, 180° ou 270°, escolhido aleatoriamente
    num_rot = int(random.random() * len(interRot))
    rot_img = image.rotate(interRot[num_rot])
    rot_img.save(os.path.join(pathBenign, f"rot_{interRot[num_rot]}_" + img))

  else:
    # Inversão horizontal e rotação
    horiz_img = image.transpose(method=Image.FLIP_LEFT_RIGHT)
    num_rot = int(random.random() * len(interRot))
    rot_hor_img = horiz_img.rotate(interRot[num_rot])
    rot_hor_img.save(os.path.join(pathBenign, f"rot_{interRot[num_rot]}_hor_flip_" + img))

  contador -= 1
# Out:
# Faltam 300 imagens
# Faltam 299 imagens
# Faltam 298 imagens
# Faltam 297 imagens
# Faltam 296 imagens
# Faltam 295 imagens
# Faltam 294 imagens
# Faltam 293 imagens
# Faltam 292 imagens
# Faltam 291 imagens
# Faltam 290 imagens
# Faltam 289 imagens
# Faltam 288 imagens
# Faltam 287 imagens
# Faltam 286 imagens
# Faltam 285 imagens
# Faltam 284 imagens
# Faltam 283 imagens
# Faltam 282 imagens
# Faltam 281 imagens
# Faltam 280 imagens
# Faltam 279 imagens
# Faltam 278 imagens
# Faltam 277 imagens
# Faltam 276 imagens
# Faltam 275 imagens
# Faltam 274 imagens
# Faltam 273 imagens
# Faltam 272 imagens
# Faltam 271 imagens
# Faltam 270 imagens
# Faltam 269 imagens
# Faltam 268 imagens
# Faltam 267 imagens
# Faltam 266 imagens
# Faltam 265 imagens
# Faltam 264 imagens
# Faltam 263 imagens
# Faltam 262 imagens
# Faltam 261 imagens
# Faltam 260 imagens
# Faltam 259 imagens
# Faltam 258 imagens
# Faltam 257 imagens
# Faltam 256 imagens
# Faltam 255 imagens
# Faltam 254 imagens
# Faltam 253 imagens
# Faltam 252 imagens
# Faltam 251 imagens
# Faltam 250 imagens
# Faltam 249 imagens
# Faltam 248 imagens
# Faltam 247 imagens
# Faltam 246 imagens
# Faltam 245 imagens
# Faltam 244 imagens
# Faltam 243 imagens
# Faltam 242 imagens
# Faltam 241 imagens
# Faltam 240 imagens
# Faltam 239 imagens
# Faltam 238 imagens
# Faltam 237 imagens
# Faltam 236 imagens
# Faltam 235 imagens
# Faltam 234 imagens
# Faltam 233 imagens
# Faltam 232 imagens
# Faltam 231 imagens
# Faltam 230 imagens
# Faltam 229 imagens
# Faltam 228 imagens
# Faltam 227 imagens
# Faltam 226 imagens
# Faltam 225 imagens
# Faltam 224 imagens
# Faltam 223 imagens
# Faltam 222 imagens
# Faltam 221 imagens
# Faltam 220 imagens
# Faltam 219 imagens
# Faltam 218 imagens
# Faltam 217 imagens
# Faltam 216 imagens
# Faltam 215 imagens
# Faltam 214 imagens
# Faltam 213 imagens
# Faltam 212 imagens
# Faltam 211 imagens
# Faltam 210 imagens
# Faltam 209 imagens
# Faltam 208 imagens
# Faltam 207 imagens
# Faltam 206 imagens
# Faltam 205 imagens
# Faltam 204 imagens
# Faltam 203 imagens
# Faltam 202 imagens
# Faltam 201 imagens
# Faltam 200 imagens
# Faltam 199 imagens
# Faltam 198 imagens
# Faltam 197 imagens
# Faltam 196 imagens
# Faltam 195 imagens
# Faltam 194 imagens
# Faltam 193 imagens
# Faltam 192 imagens
# Faltam 191 imagens
# Faltam 190 imagens
# Faltam 189 imagens
# Faltam 188 imagens
# Faltam 187 imagens
# Faltam 186 imagens
# Faltam 185 imagens
# Faltam 184 imagens
# Faltam 183 imagens
# Faltam 182 imagens
# Faltam 181 imagens
# Faltam 180 imagens
# Faltam 179 imagens
# Faltam 178 imagens
# Faltam 177 imagens
# Faltam 176 imagens
# Faltam 175 imagens
# Faltam 174 imagens
# Faltam 173 imagens
# Faltam 172 imagens
# Faltam 171 imagens
# Faltam 170 imagens
# Faltam 169 imagens
# Faltam 168 imagens
# Faltam 167 imagens
# Faltam 166 imagens
# Faltam 165 imagens
# Faltam 164 imagens
# Faltam 163 imagens
# Faltam 162 imagens
# Faltam 161 imagens
# Faltam 160 imagens
# Faltam 159 imagens
# Faltam 158 imagens
# Faltam 157 imagens
# Faltam 156 imagens
# Faltam 155 imagens
# Faltam 154 imagens
# Faltam 153 imagens
# Faltam 152 imagens
# Faltam 151 imagens
# Faltam 150 imagens
# Faltam 149 imagens
# Faltam 148 imagens
# Faltam 147 imagens
# Faltam 146 imagens
# Faltam 145 imagens
# Faltam 144 imagens
# Faltam 143 imagens
# Faltam 142 imagens
# Faltam 141 imagens
# Faltam 140 imagens
# Faltam 139 imagens
# Faltam 138 imagens
# Faltam 137 imagens
# Faltam 136 imagens
# Faltam 135 imagens
# Faltam 134 imagens
# Faltam 133 imagens
# Faltam 132 imagens
# Faltam 131 imagens
# Faltam 130 imagens
# Faltam 129 imagens
# Faltam 128 imagens
# Faltam 127 imagens
# Faltam 126 imagens
# Faltam 125 imagens
# Faltam 124 imagens
# Faltam 123 imagens
# Faltam 122 imagens
# Faltam 121 imagens
# Faltam 120 imagens
# Faltam 119 imagens
# Faltam 118 imagens
# Faltam 117 imagens
# Faltam 116 imagens
# Faltam 115 imagens
# Faltam 114 imagens
# Faltam 113 imagens
# Faltam 112 imagens
# Faltam 111 imagens
# Faltam 110 imagens
# Faltam 109 imagens
# Faltam 108 imagens
# Faltam 107 imagens
# Faltam 106 imagens
# Faltam 105 imagens
# Faltam 104 imagens
# Faltam 103 imagens
# Faltam 102 imagens
# Faltam 101 imagens
# Faltam 100 imagens
# Faltam 99 imagens
# Faltam 98 imagens
# Faltam 97 imagens
# Faltam 96 imagens
# Faltam 95 imagens
# Faltam 94 imagens
# Faltam 93 imagens
# Faltam 92 imagens
# Faltam 91 imagens
# Faltam 90 imagens
# Faltam 89 imagens
# Faltam 88 imagens
# Faltam 87 imagens
# Faltam 86 imagens
# Faltam 85 imagens
# Faltam 84 imagens
# Faltam 83 imagens
# Faltam 82 imagens
# Faltam 81 imagens
# Faltam 80 imagens
# Faltam 79 imagens
# Faltam 78 imagens
# Faltam 77 imagens
# Faltam 76 imagens
# Faltam 75 imagens
# Faltam 74 imagens
# Faltam 73 imagens
# Faltam 72 imagens
# Faltam 71 imagens
# Faltam 70 imagens
# Faltam 69 imagens
# Faltam 68 imagens
# Faltam 67 imagens
# Faltam 66 imagens
# Faltam 65 imagens
# Faltam 64 imagens
# Faltam 63 imagens
# Faltam 62 imagens
# Faltam 61 imagens
# Faltam 60 imagens
# Faltam 59 imagens
# Faltam 58 imagens
# Faltam 57 imagens
# Faltam 56 imagens
# Faltam 55 imagens
# Faltam 54 imagens
# Faltam 53 imagens
# Faltam 52 imagens
# Faltam 51 imagens
# Faltam 50 imagens
# Faltam 49 imagens
# Faltam 48 imagens
# Faltam 47 imagens
# Faltam 46 imagens
# Faltam 45 imagens
# Faltam 44 imagens
# Faltam 43 imagens
# Faltam 42 imagens
# Faltam 41 imagens
# Faltam 40 imagens
# Faltam 39 imagens
# Faltam 38 imagens
# Faltam 37 imagens
# Faltam 36 imagens
# Faltam 35 imagens
# Faltam 34 imagens
# Faltam 33 imagens
# Faltam 32 imagens
# Faltam 31 imagens
# Faltam 30 imagens
# Faltam 29 imagens
# Faltam 28 imagens
# Faltam 27 imagens
# Faltam 26 imagens
# Faltam 25 imagens
# Faltam 24 imagens
# Faltam 23 imagens
# Faltam 22 imagens
# Faltam 21 imagens
# Faltam 20 imagens
# Faltam 19 imagens
# Faltam 18 imagens
# Faltam 17 imagens
# Faltam 16 imagens
# Faltam 15 imagens
# Faltam 14 imagens
# Faltam 13 imagens
# Faltam 12 imagens
# Faltam 11 imagens
# Faltam 10 imagens
# Faltam 9 imagens
# Faltam 8 imagens
# Faltam 7 imagens
# Faltam 6 imagens
# Faltam 5 imagens
# Faltam 4 imagens
# Faltam 3 imagens
# Faltam 2 imagens
# Faltam 1 imagens

# %% [markdown]
# #**INICIALIZANDO O DATASET**
#
# ---

# %%
pastaDataset = "./dataset/"
# Carregando as imagens do drive
(train_ds, val_ds) = keras.utils.image_dataset_from_directory(pastaDataset, labels='inferred',image_size=(1024, 768), label_mode="int", batch_size=1, subset="both", validation_split=0.3, seed=123)

classes = train_ds.class_names

# 70% para treino, 20% para validação e 10% para teste
val_batches = tf.data.experimental.cardinality(val_ds)
test_ds = val_ds.take(val_batches // 3)
val_ds = val_ds.skip(val_batches // 3)

# Normalização para que os valores na matriz referentes aos pixels fiquem entre 0 e 1
normalization_layer = tf.keras.layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y))
# Out:
# Found 3542 files belonging to 4 classes.
# Using 2480 files for training.
# Using 1062 files for validation.

# %%
classes
# Out:
# ['Benign', '[Malignant] Pre-B', '[Malignant] Pro-B', '[Malignant] early Pre-B']

# %% [markdown]
# #**VISUALIZAÇÃO**
#
# > Aqui não têm muito segredo, uma imagem vale mais do que 12x12 palavras.
#
# ---

# %%
imagens = [benign[0], pre_b[0], pro_b[0], early_pre_b[0]]

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 6))
axes = axes.flatten()
for i, classe in enumerate(classes):
  img = cv2.imread(f"./dataset/{classe}/{imagens[i]}")
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  axes[i].imshow(img)
  axes[i].set_title(classe)
  axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# #**TREINANDO O MODELO**
# > Treinaremos o nosso modelo Target agora utilizando um modelo pré-treinado (Source Model), o qual citamos no slide desta aula, InceptionV3, utilizando sua capacidade de reconhecimentos de características para suprir a nossa necessidade.
#
# > _Link para a documentaçao:_ https://www.tensorflow.org/tutorials/images/transfer_learning?hl=pt-br#feature_extraction
#
# ---

# %%
from keras.applications import InceptionV3
def treinar_modelo(modelo, epochs):
  # Caso o treino seja interrompido por algum motivo, o estado do modelo é salvo pelo callback para que possa ser retomado posteriormente
  backup = f"./backup/{str(modelo)[10:str(modelo).index("at") - 1]}.keras"
  model_callback = keras.callbacks.BackupAndRestore(backup, save_freq="epoch", double_checkpoint=False, delete_checkpoint=False)

  # Carregando o modelo pré treinado e congelando essa base
  base_model = InceptionV3(weights="imagenet", include_top=False, input_shape=(1024, 768, 3))
  base_model.trainable = False

  inputs = keras.Input(shape=(1024, 768, 3))
  x = base_model(inputs, training=False)
  x = keras.layers.GlobalAveragePooling2D()(x)
  outputs = keras.layers.Dense(4, activation='softmax')(x)
  model = keras.Model(inputs, outputs)

  model.compile(loss='sparse_categorical_crossentropy', optimizer="adam", metrics=['accuracy'])
  model.summary()
  history = model.fit(train_ds, epochs=epochs, validation_data=val_ds, callbacks=[model_callback])
  model.save(f"./modelos_treinados/{str(modelo)[10:str(modelo).index("at") - 1]}.keras")
  return (model, history)

# %%
modelo, history = treinar_modelo(InceptionV3, 5)
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_11 (InputLayer)     │ (None, 1024, 768, 3)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 30, 22, 2048)   │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_5      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │         8,196 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,810,980 (83.20 MB)
#  Trainable params: 8,196 (32.02 KB)
#  Non-trainable params: 21,802,784 (83.17 MB)
# Epoch 1/5
# 2480/2480 ━━━━━━━━━━━━━━━━━━━━ 165s 61ms/step - accuracy: 0.8358 - loss: 0.4954 - val_accuracy: 0.9689 - val_loss: 0.1214
# Epoch 2/5
# 2480/2480 ━━━━━━━━━━━━━━━━━━━━ 142s 57ms/step - accuracy: 0.9642 - loss: 0.1094 - val_accuracy: 0.9732 - val_loss: 0.0904
# Epoch 3/5
# 2480/2480 ━━━━━━━━━━━━━━━━━━━━ 144s 58ms/step - accuracy: 0.9683 - loss: 0.0865 - val_accuracy: 0.9661 - val_loss: 0.1067
# Epoch 4/5
# 2480/2480 ━━━━━━━━━━━━━━━━━━━━ 142s 57ms/step - accuracy: 0.9783 - loss: 0.0613 - val_accuracy: 0.9718 - val_loss: 0.0940
# Epoch 5/5
# 2480/2480 ━━━━━━━━━━━━━━━━━━━━ 203s 58ms/step - accuracy: 0.9822 - loss: 0.0525 - val_accuracy: 0.9689 - val_loss: 0.1059

# %% [markdown]
# #**FINE TUNING**
#
# > Apesar de ser uma etapa opcional, a utilizaremos aqui para refinar nosso modelo Target após a etapa de compartilhamento de conhecimento geral, realizada no transfer learning, com o modelo InceptionV3.
#
# ---

# %%
from keras.models import load_model
modelo = load_model("./modelos_treinados/InceptionV3.keras")

# %%
modelo
# Out:
# <Functional name=functional_5, built=True>

# %%
modelo.layers[:]
# Out:
# [<InputLayer name=input_layer_11, built=True>,
#  <Functional name=inception_v3, built=True>,
#  <GlobalAveragePooling2D name=global_average_pooling2d_5, built=True>,
#  <Dense name=dense_5, built=True>]

# %%
# Visualizando as camadas que existem dentro do modelo base (InceptionV3)
modelo.layers[1].layers[:]
# Out:
# [<InputLayer name=input_layer_10, built=True>,
#  <Conv2D name=conv2d_470, built=True>,
#  <BatchNormalization name=batch_normalization_470, built=True>,
#  <Activation name=activation_470, built=True>,
#  <Conv2D name=conv2d_471, built=True>,
#  <BatchNormalization name=batch_normalization_471, built=True>,
#  <Activation name=activation_471, built=True>,
#  <Conv2D name=conv2d_472, built=True>,
#  <BatchNormalization name=batch_normalization_472, built=True>,
#  <Activation name=activation_472, built=True>,
#  <MaxPooling2D name=max_pooling2d_20, built=True>,
#  <Conv2D name=conv2d_473, built=True>,
#  <BatchNormalization name=batch_normalization_473, built=True>,
#  <Activation name=activation_473, built=True>,
#  <Conv2D name=conv2d_474, built=True>,
#  <BatchNormalization name=batch_normalization_474, built=True>,
#  <Activation name=activation_474, built=True>,
#  <MaxPooling2D name=max_pooling2d_21, built=True>,
#  <Conv2D name=conv2d_478, built=True>,
#  <BatchNormalization name=batch_normalization_478, built=True>,
#  <Activation name=activation_478, built=True>,
#  <Conv2D name=conv2d_476, built=True>,
#  <Conv2D name=conv2d_479, built=True>,
#  <BatchNormalization name=batch_normalization_476, built=True>,
#  <BatchNormalization name=batch_normalization_479, built=True>,
#  <Activation name=activation_476, built=True>,
#  <Activation name=activation_479, built=True>,
#  <AveragePooling2D name=average_pooling2d_45, built=True>,
#  <Conv2D name=conv2d_475, built=True>,
#  <Conv2D name=conv2d_477, built=True>,
#  <Conv2D name=conv2d_480, built=True>,
#  <Conv2D name=conv2d_481, built=True>,
#  <BatchNormalization name=batch_normalization_475, built=True>,
#  <BatchNormalization name=batch_normalization_477, built=True>,
#  <BatchNormalization name=batch_normalization_480, built=True>,
#  <BatchNormalization name=batch_normalization_481, built=True>,
#  <Activation name=activation_475, built=True>,
#  <Activation name=activation_477, built=True>,
#  <Activation name=activation_480, built=True>,
#  <Activation name=activation_481, built=True>,
#  <Concatenate name=mixed0, built=True>,
#  <Conv2D name=conv2d_485, built=True>,
#  <BatchNormalization name=batch_normalization_485, built=True>,
#  <Activation name=activation_485, built=True>,
#  <Conv2D name=conv2d_483, built=True>,
#  <Conv2D name=conv2d_486, built=True>,
#  <BatchNormalization name=batch_normalization_483, built=True>,
#  <BatchNormalization name=batch_normalization_486, built=True>,
#  <Activation name=activation_483, built=True>,
#  <Activation name=activation_486, built=True>,
#  <AveragePooling2D name=average_pooling2d_46, built=True>,
#  <Conv2D name=conv2d_482, built=True>,
#  <Conv2D name=conv2d_484, built=True>,
#  <Conv2D name=conv2d_487, built=True>,
#  <Conv2D name=conv2d_488, built=True>,
#  <BatchNormalization name=batch_normalization_482, built=True>,
#  <BatchNormalization name=batch_normalization_484, built=True>,
#  <BatchNormalization name=batch_normalization_487, built=True>,
#  <BatchNormalization name=batch_normalization_488, built=True>,
#  <Activation name=activation_482, built=True>,
#  <Activation name=activation_484, built=True>,
#  <Activation name=activation_487, built=True>,
#  <Activation name=activation_488, built=True>,
#  <Concatenate name=mixed1, built=True>,
#  <Conv2D name=conv2d_492, built=True>,
#  <BatchNormalization name=batch_normalization_492, built=True>,
#  <Activation name=activation_492, built=True>,
#  <Conv2D name=conv2d_490, built=True>,
#  <Conv2D name=conv2d_493, built=True>,
#  <BatchNormalization name=batch_normalization_490, built=True>,
#  <BatchNormalization name=batch_normalization_493, built=True>,
#  <Activation name=activation_490, built=True>,
#  <Activation name=activation_493, built=True>,
#  <AveragePooling2D name=average_pooling2d_47, built=True>,
#  <Conv2D name=conv2d_489, built=True>,
#  <Conv2D name=conv2d_491, built=True>,
#  <Conv2D name=conv2d_494, built=True>,
#  <Conv2D name=conv2d_495, built=True>,
#  <BatchNormalization name=batch_normalization_489, built=True>,
#  <BatchNormalization name=batch_normalization_491, built=True>,
#  <BatchNormalization name=batch_normalization_494, built=True>,
#  <BatchNormalization name=batch_normalization_495, built=True>,
#  <Activation name=activation_489, built=True>,
#  <Activation name=activation_491, built=True>,
#  <Activation name=activation_494, built=True>,
#  <Activation name=activation_495, built=True>,
#  <Concatenate name=mixed2, built=True>,
#  <Conv2D name=conv2d_497, built=True>,
#  <BatchNormalization name=batch_normalization_497, built=True>,
#  <Activation name=activation_497, built=True>,
#  <Conv2D name=conv2d_498, built=True>,
#  <BatchNormalization name=batch_normalization_498, built=True>,
#  <Activation name=activation_498, built=True>,
#  <Conv2D name=conv2d_496, built=True>,
#  <Conv2D name=conv2d_499, built=True>,
#  <BatchNormalization name=batch_normalization_496, built=True>,
#  <BatchNormalization name=batch_normalization_499, built=True>,
#  <Activation name=activation_496, built=True>,
#  <Activation name=activation_499, built=True>,
#  <MaxPooling2D name=max_pooling2d_22, built=True>,
#  <Concatenate name=mixed3, built=True>,
#  <Conv2D name=conv2d_504, built=True>,
#  <BatchNormalization name=batch_normalization_504, built=True>,
#  <Activation name=activation_504, built=True>,
#  <Conv2D name=conv2d_505, built=True>,
#  <BatchNormalization name=batch_normalization_505, built=True>,
#  <Activation name=activation_505, built=True>,
#  <Conv2D name=conv2d_501, built=True>,
#  <Conv2D name=conv2d_506, built=True>,
#  <BatchNormalization name=batch_normalization_501, built=True>,
#  <BatchNormalization name=batch_normalization_506, built=True>,
#  <Activation name=activation_501, built=True>,
#  <Activation name=activation_506, built=True>,
#  <Conv2D name=conv2d_502, built=True>,
#  <Conv2D name=conv2d_507, built=True>,
#  <BatchNormalization name=batch_normalization_502, built=True>,
#  <BatchNormalization name=batch_normalization_507, built=True>,
#  <Activation name=activation_502, built=True>,
#  <Activation name=activation_507, built=True>,
#  <AveragePooling2D name=average_pooling2d_48, built=True>,
#  <Conv2D name=conv2d_500, built=True>,
#  <Conv2D name=conv2d_503, built=True>,
#  <Conv2D name=conv2d_508, built=True>,
#  <Conv2D name=conv2d_509, built=True>,
#  <BatchNormalization name=batch_normalization_500, built=True>,
#  <BatchNormalization name=batch_normalization_503, built=True>,
#  <BatchNormalization name=batch_normalization_508, built=True>,
#  <BatchNormalization name=batch_normalization_509, built=True>,
#  <Activation name=activation_500, built=True>,
#  <Activation name=activation_503, built=True>,
#  <Activation name=activation_508, built=True>,
#  <Activation name=activation_509, built=True>,
#  <Concatenate name=mixed4, built=True>,
#  <Conv2D name=conv2d_514, built=True>,
#  <BatchNormalization name=batch_normalization_514, built=True>,
#  <Activation name=activation_514, built=True>,
#  <Conv2D name=conv2d_515, built=True>,
#  <BatchNormalization name=batch_normalization_515, built=True>,
#  <Activation name=activation_515, built=True>,
#  <Conv2D name=conv2d_511, built=True>,
#  <Conv2D name=conv2d_516, built=True>,
#  <BatchNormalization name=batch_normalization_511, built=True>,
#  <BatchNormalization name=batch_normalization_516, built=True>,
#  <Activation name=activation_511, built=True>,
#  <Activation name=activation_516, built=True>,
#  <Conv2D name=conv2d_512, built=True>,
#  <Conv2D name=conv2d_517, built=True>,
#  <BatchNormalization name=batch_normalization_512, built=True>,
#  <BatchNormalization name=batch_normalization_517, built=True>,
#  <Activation name=activation_512, built=True>,
#  <Activation name=activation_517, built=True>,
#  <AveragePooling2D name=average_pooling2d_49, built=True>,
#  <Conv2D name=conv2d_510, built=True>,
#  <Conv2D name=conv2d_513, built=True>,
#  <Conv2D name=conv2d_518, built=True>,
#  <Conv2D name=conv2d_519, built=True>,
#  <BatchNormalization name=batch_normalization_510, built=True>,
#  <BatchNormalization name=batch_normalization_513, built=True>,
#  <BatchNormalization name=batch_normalization_518, built=True>,
#  <BatchNormalization name=batch_normalization_519, built=True>,
#  <Activation name=activation_510, built=True>,
#  <Activation name=activation_513, built=True>,
#  <Activation name=activation_518, built=True>,
#  <Activation name=activation_519, built=True>,
#  <Concatenate name=mixed5, built=True>,
#  <Conv2D name=conv2d_524, built=True>,
#  <BatchNormalization name=batch_normalization_524, built=True>,
#  <Activation name=activation_524, built=True>,
#  <Conv2D name=conv2d_525, built=True>,
#  <BatchNormalization name=batch_normalization_525, built=True>,
#  <Activation name=activation_525, built=True>,
#  <Conv2D name=conv2d_521, built=True>,
#  <Conv2D name=conv2d_526, built=True>,
#  <BatchNormalization name=batch_normalization_521, built=True>,
#  <BatchNormalization name=batch_normalization_526, built=True>,
#  <Activation name=activation_521, built=True>,
#  <Activation name=activation_526, built=True>,
#  <Conv2D name=conv2d_522, built=True>,
#  <Conv2D name=conv2d_527, built=True>,
#  <BatchNormalization name=batch_normalization_522, built=True>,
#  <BatchNormalization name=batch_normalization_527, built=True>,
#  <Activation name=activation_522, built=True>,
#  <Activation name=activation_527, built=True>,
#  <AveragePooling2D name=average_pooling2d_50, built=True>,
#  <Conv2D name=conv2d_520, built=True>,
#  <Conv2D name=conv2d_523, built=True>,
#  <Conv2D name=conv2d_528, built=True>,
#  <Conv2D name=conv2d_529, built=True>,
#  <BatchNormalization name=batch_normalization_520, built=True>,
#  <BatchNormalization name=batch_normalization_523, built=True>,
#  <BatchNormalization name=batch_normalization_528, built=True>,
#  <BatchNormalization name=batch_normalization_529, built=True>,
#  <Activation name=activation_520, built=True>,
#  <Activation name=activation_523, built=True>,
#  <Activation name=activation_528, built=True>,
#  <Activation name=activation_529, built=True>,
#  <Concatenate name=mixed6, built=True>,
#  <Conv2D name=conv2d_534, built=True>,
#  <BatchNormalization name=batch_normalization_534, built=True>,
#  <Activation name=activation_534, built=True>,
#  <Conv2D name=conv2d_535, built=True>,
#  <BatchNormalization name=batch_normalization_535, built=True>,
#  <Activation name=activation_535, built=True>,
#  <Conv2D name=conv2d_531, built=True>,
#  <Conv2D name=conv2d_536, built=True>,
#  <BatchNormalization name=batch_normalization_531, built=True>,
#  <BatchNormalization name=batch_normalization_536, built=True>,
#  <Activation name=activation_531, built=True>,
#  <Activation name=activation_536, built=True>,
#  <Conv2D name=conv2d_532, built=True>,
#  <Conv2D name=conv2d_537, built=True>,
#  <BatchNormalization name=batch_normalization_532, built=True>,
#  <BatchNormalization name=batch_normalization_537, built=True>,
#  <Activation name=activation_532, built=True>,
#  <Activation name=activation_537, built=True>,
#  <AveragePooling2D name=average_pooling2d_51, built=True>,
#  <Conv2D name=conv2d_530, built=True>,
#  <Conv2D name=conv2d_533, built=True>,
#  <Conv2D name=conv2d_538, built=True>,
#  <Conv2D name=conv2d_539, built=True>,
#  <BatchNormalization name=batch_normalization_530, built=True>,
#  <BatchNormalization name=batch_normalization_533, built=True>,
#  <BatchNormalization name=batch_normalization_538, built=True>,
#  <BatchNormalization name=batch_normalization_539, built=True>,
#  <Activation name=activation_530, built=True>,
#  <Activation name=activation_533, built=True>,
#  <Activation name=activation_538, built=True>,
#  <Activation name=activation_539, built=True>,
#  <Concatenate name=mixed7, built=True>,
#  <Conv2D name=conv2d_542, built=True>,
#  <BatchNormalization name=batch_normalization_542, built=True>,
#  <Activation name=activation_542, built=True>,
#  <Conv2D name=conv2d_543, built=True>,
#  <BatchNormalization name=batch_normalization_543, built=True>,
#  <Activation name=activation_543, built=True>,
#  <Conv2D name=conv2d_540, built=True>,
#  <Conv2D name=conv2d_544, built=True>,
#  <BatchNormalization name=batch_normalization_540, built=True>,
#  <BatchNormalization name=batch_normalization_544, built=True>,
#  <Activation name=activation_540, built=True>,
#  <Activation name=activation_544, built=True>,
#  <Conv2D name=conv2d_541, built=True>,
#  <Conv2D name=conv2d_545, built=True>,
#  <BatchNormalization name=batch_normalization_541, built=True>,
#  <BatchNormalization name=batch_normalization_545, built=True>,
#  <Activation name=activation_541, built=True>,
#  <Activation name=activation_545, built=True>,
#  <MaxPooling2D name=max_pooling2d_23, built=True>,
#  <Concatenate name=mixed8, built=True>,
#  <Conv2D name=conv2d_550, built=True>,
#  <BatchNormalization name=batch_normalization_550, built=True>,
#  <Activation name=activation_550, built=True>,
#  <Conv2D name=conv2d_547, built=True>,
#  <Conv2D name=conv2d_551, built=True>,
#  <BatchNormalization name=batch_normalization_547, built=True>,
#  <BatchNormalization name=batch_normalization_551, built=True>,
#  <Activation name=activation_547, built=True>,
#  <Activation name=activation_551, built=True>,
#  <Conv2D name=conv2d_548, built=True>,
#  <Conv2D name=conv2d_549, built=True>,
#  <Conv2D name=conv2d_552, built=True>,
#  <Conv2D name=conv2d_553, built=True>,
#  <AveragePooling2D name=average_pooling2d_52, built=True>,
#  <Conv2D name=conv2d_546, built=True>,
#  <BatchNormalization name=batch_normalization_548, built=True>,
#  <BatchNormalization name=batch_normalization_549, built=True>,
#  <BatchNormalization name=batch_normalization_552, built=True>,
#  <BatchNormalization name=batch_normalization_553, built=True>,
#  <Conv2D name=conv2d_554, built=True>,
#  <BatchNormalization name=batch_normalization_546, built=True>,
#  <Activation name=activation_548, built=True>,
#  <Activation name=activation_549, built=True>,
#  <Activation name=activation_552, built=True>,
#  <Activation name=activation_553, built=True>,
#  <BatchNormalization name=batch_normalization_554, built=True>,
#  <Activation name=activation_546, built=True>,
#  <Concatenate name=mixed9_0, built=True>,
#  <Concatenate name=concatenate_10, built=True>,
#  <Activation name=activation_554, built=True>,
#  <Concatenate name=mixed9, built=True>,
#  <Conv2D name=conv2d_559, built=True>,
#  <BatchNormalization name=batch_normalization_559, built=True>,
#  <Activation name=activation_559, built=True>,
#  <Conv2D name=conv2d_556, built=True>,
#  <Conv2D name=conv2d_560, built=True>,
#  <BatchNormalization name=batch_normalization_556, built=True>,
#  <BatchNormalization name=batch_normalization_560, built=True>,
#  <Activation name=activation_556, built=True>,
#  <Activation name=activation_560, built=True>,
#  <Conv2D name=conv2d_557, built=True>,
#  <Conv2D name=conv2d_558, built=True>,
#  <Conv2D name=conv2d_561, built=True>,
#  <Conv2D name=conv2d_562, built=True>,
#  <AveragePooling2D name=average_pooling2d_53, built=True>,
#  <Conv2D name=conv2d_555, built=True>,
#  <BatchNormalization name=batch_normalization_557, built=True>,
#  <BatchNormalization name=batch_normalization_558, built=True>,
#  <BatchNormalization name=batch_normalization_561, built=True>,
#  <BatchNormalization name=batch_normalization_562, built=True>,
#  <Conv2D name=conv2d_563, built=True>,
#  <BatchNormalization name=batch_normalization_555, built=True>,
#  <Activation name=activation_557, built=True>,
#  <Activation name=activation_558, built=True>,
#  <Activation name=activation_561, built=True>,
#  <Activation name=activation_562, built=True>,
#  <BatchNormalization name=batch_normalization_563, built=True>,
#  <Activation name=activation_555, built=True>,
#  <Concatenate name=mixed9_1, built=True>,
#  <Concatenate name=concatenate_11, built=True>,
#  <Activation name=activation_563, built=True>,
#  <Concatenate name=mixed10, built=True>]

# %%
len(modelo.layers[1].layers[:])
# Out:
# 311

# %%
fine_tune_at = 261
for layer in modelo.layers[1].layers[:fine_tune_at]:
  layer.trainable = False

backup = f'./backup/finetuning_InceptionV3.keras'
model_callback = keras.callbacks.BackupAndRestore(backup, save_freq="epoch", double_checkpoint=False, delete_checkpoint=False)
modelo.compile(loss='sparse_categorical_crossentropy', optimizer="adam", metrics=['accuracy'])
history = modelo.fit(train_ds, epochs=3, validation_data=val_ds, callbacks=[model_callback])
modelo.save("./modelos_treinados/finetuning_InceptionV3.keras")
# Out:
# Epoch 1/3
# 2480/2480 ━━━━━━━━━━━━━━━━━━━━ 184s 61ms/step - accuracy: 0.9874 - loss: 0.0457 - val_accuracy: 0.9477 - val_loss: 0.1435
# Epoch 2/3
# 2480/2480 ━━━━━━━━━━━━━━━━━━━━ 179s 58ms/step - accuracy: 0.9880 - loss: 0.0398 - val_accuracy: 0.9647 - val_loss: 0.0995
# Epoch 3/3
# 2480/2480 ━━━━━━━━━━━━━━━━━━━━ 144s 58ms/step - accuracy: 0.9897 - loss: 0.0318 - val_accuracy: 0.9590 - val_loss: 0.1149

# %% [markdown]
# #**MÉTRICAS DE DESEMPENHO**
#
#
# <img src="https://eailab.labmax.org/wp-content/uploads/2025/05/image-24.png" width="550">
#
# ---

# %%
modelo = load_model("./modelos_treinados/finetuning_InceptionV3.keras")

# %%
modelo.evaluate(val_ds)
# Out:
# 708/708 ━━━━━━━━━━━━━━━━━━━━ 45s 42ms/step - accuracy: 0.9579 - loss: 0.1251
# [0.11490607261657715, 0.959039568901062]

# %%
# Evolução da acurácia durante o treino
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.show()

# %%
# Evolução da perda durante o treino
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.show()

# %%
predicoes = modelo.predict(test_ds)
# Out:
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 26s 52ms/step

# %%
# Array com as probabilidades para cada classe
predicoes[0]
# Out:
# array([2.0445458e-04, 1.8487547e-01, 8.1487125e-01, 4.8788610e-05],
#       dtype=float32)

# %%
predicoes_labels = [np.argmax(i) for i in predicoes]

# %%
y_test = []
for x, y in test_ds:
  label = int(y.numpy()[0])
  y_test.append(label)

# %%
# Mostra as metricas de desempenho do teste
from sklearn.metrics import f1_score, classification_report
print(classification_report(y_test, predicoes_labels, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.986     0.986     0.986        70
#            1      0.892     1.000     0.943        83
#            2      1.000     0.913     0.955       104
#            3      0.990     0.979     0.984        97
#
#     accuracy                          0.966       354
#    macro avg      0.967     0.970     0.967       354
# weighted avg      0.969     0.966     0.966       354

# %%
import seaborn as sn

# Matriz de confusão:
confusion_matrix = tf.math.confusion_matrix(labels=y_test, predictions=predicoes_labels)
sn.heatmap(confusion_matrix, annot=True, fmt='d');
